# %%
from nbapy import scoreboard
import pandas as pd
pd.set_option('max_columns', None)

# %% [markdown]
# # game_header

# %%
scoreboard.Scoreboard(12,25,2019).game_header()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2019-12-25T00:00:00              1  0021900455               3
# 1  2019-12-25T00:00:00              2  0021900456               3
# 2  2019-12-25T00:00:00              3  0021900457               3
# 3  2019-12-25T00:00:00              4  0021900458               3
# 4  2019-12-25T00:00:00              5  0021900459               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20191225/BOSTOR    1610612761       1610612738   2019
# 1            Final  20191225/MILPHI    1610612755       1610612749   2019
# 2            Final  20191225/HOUGSW    1610612744       1610612745   2019
# 3            Final  20191225/LACLAL    1610612747       1610612746   2019
# 4            Final  20191225/NOPDEN    1610612743       1610612740   2019
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# ...

# %% [markdown]
# # line_score

# %%
scoreboard.Scoreboard(12,25,2019).line_score()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2019-12-25T00:00:00              1  0021900455  1610612738
# 1  2019-12-25T00:00:00              1  0021900455  1610612761
# 2  2019-12-25T00:00:00              2  0021900456  1610612749
# 3  2019-12-25T00:00:00              2  0021900456  1610612755
# 4  2019-12-25T00:00:00              3  0021900457  1610612745
# 5  2019-12-25T00:00:00              3  0021900457  1610612744
# 6  2019-12-25T00:00:00              4  0021900458  1610612746
# 7  2019-12-25T00:00:00              4  0021900458  1610612747
# 8  2019-12-25T00:00:00              5  0021900459  1610612740
# 9  2019-12-25T00:00:00              5  0021900459  1610612743
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_WINS_LOSSES  PTS_QTR1  PTS_QTR2  \
# 0               BOS         Boston             21-7        28        27
# 1               TOR        Toronto            21-10        19        28
# ...

# %% [markdown]
# # series_standings

# %%
scoreboard.Scoreboard(12,25,2019).series_standings()
# Out:
#       GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        GAME_DATE_EST  \
# 0  0021900459    1610612743       1610612740  2019-12-25T00:00:00
# 1  0021900457    1610612744       1610612745  2019-12-25T00:00:00
# 2  0021900458    1610612747       1610612746  2019-12-25T00:00:00
# 3  0021900456    1610612755       1610612749  2019-12-25T00:00:00
# 4  0021900455    1610612761       1610612738  2019-12-25T00:00:00
#
#    HOME_TEAM_WINS  HOME_TEAM_LOSSES SERIES_LEADER
# 0               1                 2   New Orleans
# 1               1                 2       Houston
# 2               1                 2   LA Clippers
# 3               1                 2     Milwaukee
# 4               1                 2        Boston

# %% [markdown]
# # last_meeting

# %%
scoreboard.Scoreboard(12,25,2019).last_meeting()
# Out:
#       GAME_ID LAST_GAME_ID   LAST_GAME_DATE_EST  LAST_GAME_HOME_TEAM_ID  \
# 0  0021900455   0021900017  2019-10-25T00:00:00              1610612761
# 1  0021900456   0021801177  2019-04-04T00:00:00              1610612755
# 2  0021900457   0021900107  2019-11-06T00:00:00              1610612744
# 3  0021900458   0021900002  2019-10-22T00:00:00              1610612747
# 4  0021900459   0021900067  2019-10-31T00:00:00              1610612743
#
#   LAST_GAME_HOME_TEAM_CITY LAST_GAME_HOME_TEAM_NAME  \
# 0                  Toronto                  Raptors
# 1             Philadelphia                    76ers
# 2             Golden State                 Warriors
# 3              Los Angeles                   Lakers
# 4                   Denver                  Nuggets
#
#   LAST_GAME_HOME_TEAM_ABBREVIATION  LAST_GAME_HOME_TEAM_POINTS  \
# 0                              TOR                         106
# 1                              PHI                         122
# ...

# %% [markdown]
# # east_conf_standings_by_day

# %%
scoreboard.Scoreboard(12,25,2019).east_conf_standings_by_day()
# Out:
#        TEAM_ID LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE          TEAM   G  \
# 0   1610612749        00     22019    12/25/2019       East     Milwaukee  32
# 1   1610612738        00     22019    12/25/2019       East        Boston  28
# 2   1610612748        00     22019    12/25/2019       East         Miami  30
# 3   1610612755        00     22019    12/25/2019       East  Philadelphia  33
# 4   1610612754        00     22019    12/25/2019       East       Indiana  31
# 5   1610612761        00     22019    12/25/2019       East       Toronto  31
# 6   1610612751        00     22019    12/25/2019       East      Brooklyn  29
# 7   1610612753        00     22019    12/25/2019       East       Orlando  30
# 8   1610612766        00     22019    12/25/2019       East     Charlotte  33
# 9   1610612741        00     22019    12/25/2019       East       Chicago  32
# 10  1610612765        00     22019    12/25/2019       East       Detroit  31
# ...

# %% [markdown]
# # west_conf_standings_by_day

# %%
scoreboard.Scoreboard(12,25,2019).west_conf_standings_by_day()
# Out:
#        TEAM_ID LEAGUE_ID SEASON_ID STANDINGSDATE CONFERENCE           TEAM  \
# 0   1610612747        00     22019    12/25/2019       West    L.A. Lakers
# 1   1610612743        00     22019    12/25/2019       West         Denver
# 2   1610612746        00     22019    12/25/2019       West    LA Clippers
# 3   1610612745        00     22019    12/25/2019       West        Houston
# 4   1610612742        00     22019    12/25/2019       West         Dallas
# 5   1610612762        00     22019    12/25/2019       West           Utah
# 6   1610612760        00     22019    12/25/2019       West  Oklahoma City
# 7   1610612757        00     22019    12/25/2019       West       Portland
# 8   1610612759        00     22019    12/25/2019       West    San Antonio
# 9   1610612758        00     22019    12/25/2019       West     Sacramento
# 10  1610612756        00     22019    12/25/2019       West        Phoenix
# ...

# %% [markdown]
# # available

# %%
scoreboard.Scoreboard(12,25,2019).available()
# Out:
#       GAME_ID  PT_AVAILABLE
# 0  0021900455             1
# 1  0021900458             1
# 2  0021900456             1
# 3  0021900457             1
# 4  0021900459             1
