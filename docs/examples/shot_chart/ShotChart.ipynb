# %%
from nbapy import shot_chart
import pandas as pd

player_id = '1628369'

# %% [markdown]
# # shot_chart

# %%
pd.DataFrame(shot_chart.ShotChart(player_id).shot_chart())
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0    Shot Chart Detail  0021900008              7    1628369  Jayson Tatum
# 1    Shot Chart Detail  0021900008             76    1628369  Jayson Tatum
# 2    Shot Chart Detail  0021900008            100    1628369  Jayson Tatum
# 3    Shot Chart Detail  0021900008            107    1628369  Jayson Tatum
# 4    Shot Chart Detail  0021900008            122    1628369  Jayson Tatum
# ..                 ...         ...            ...        ...           ...
# 500  Shot Chart Detail  0021900440            552    1628369  Jayson Tatum
# 501  Shot Chart Detail  0021900440            578    1628369  Jayson Tatum
# 502  Shot Chart Detail  0021900440            581    1628369  Jayson Tatum
# 503  Shot Chart Detail  0021900440            586    1628369  Jayson Tatum
# 504  Shot Chart Detail  0021900440            611    1628369  Jayson Tatum
#
# ...

# %% [markdown]
# # league_average

# %%
pd.DataFrame(shot_chart.ShotChart(player_id).league_average())
# Out:
#           GRID_TYPE        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 0   League Averages      Above the Break 3         Back Court(BC)
# 1   League Averages      Above the Break 3              Center(C)
# 2   League Averages      Above the Break 3   Left Side Center(LC)
# 3   League Averages      Above the Break 3  Right Side Center(RC)
# 4   League Averages              Backcourt         Back Court(BC)
# 5   League Averages  In The Paint (Non-RA)              Center(C)
# 6   League Averages  In The Paint (Non-RA)              Center(C)
# 7   League Averages  In The Paint (Non-RA)           Left Side(L)
# 8   League Averages  In The Paint (Non-RA)          Right Side(R)
# 9   League Averages          Left Corner 3           Left Side(L)
# 10  League Averages              Mid-Range              Center(C)
# 11  League Averages              Mid-Range              Center(C)
# 12  League Averages              Mid-Range   Left Side Center(LC)
# ...
