# %%
from nbapy import game
import pandas as pd
pd.set_option('max_columns', None)

game_id = '0021900017'

# %% [markdown]
# # stats

# %%
game.PlayByPlay(game_id).stats()
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0    0021900017         2            12                   0       1
# 1    0021900017         4            10                   0       1
# 2    0021900017         8             2                 101       1
# 3    0021900017         9             4                   0       1
# 4    0021900017        10             2                 101       1
# ..          ...       ...           ...                 ...     ...
# 482  0021900017       686             3                  12       4
# 483  0021900017       687             9                   1       4
# 484  0021900017       688             6                   4       4
# 485  0021900017       690             5                  37       4
# 486  0021900017       691            13                   0       4
#
#     WCTIMESTRING PCTIMESTRING                             HOMEDESCRIPTION  \
# 0        7:11 PM        12:00                                        None
# ...

# %% [markdown]
# # available_video

# %%
game.PlayByPlay(game_id).available_video()
# Out:
#    VIDEO_AVAILABLE_FLAG
# 0                     1
