# %%
from nbapy import game
import pandas as pd

game_id = '0021900017'

# %% [markdown]
# # players_stats

# %%
pd.DataFrame(game.BoxScoreHustle(game_id).players_stats())
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 0   0021900017  1610612761               TOR   Toronto    1628384
# 1   0021900017  1610612761               TOR   Toronto    1627783
# 2   0021900017  1610612761               TOR   Toronto     201188
# 3   0021900017  1610612761               TOR   Toronto     200768
# 4   0021900017  1610612761               TOR   Toronto    1627832
# 5   0021900017  1610612761               TOR   Toronto    1626181
# 6   0021900017  1610612761               TOR   Toronto     201586
# 7   0021900017  1610612761               TOR   Toronto    1629056
# 8   0021900017  1610612761               TOR   Toronto    1626169
# 9   0021900017  1610612738               BOS    Boston    1628369
# 10  0021900017  1610612738               BOS    Boston     202330
# 11  0021900017  1610612738               BOS    Boston    1628464
# 12  0021900017  1610612738               BOS    Boston    1627759
# ...

# %% [markdown]
# # team_stats

# %%
pd.DataFrame(game.BoxScoreHustle(game_id).team_stats())
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION TEAM_CITY  \
# 0  0021900017  1610612761   Raptors               TOR   Toronto
# 1  0021900017  1610612738   Celtics               BOS    Boston
#
#          MINUTES  PTS  CONTESTED_SHOTS  CONTESTED_SHOTS_2PT  \
# 0  240.000000:00  106               69                   46
# 1  240.000000:00  112               57                   35
#
#    CONTESTED_SHOTS_3PT  ...  SCREEN_ASSISTS  SCREEN_AST_PTS  \
# 0                   23  ...               9              24
# 1                   22  ...              12              28
#
#    OFF_LOOSE_BALLS_RECOVERED  DEF_LOOSE_BALLS_RECOVERED  \
# 0                          3                          5
# 1                          3                          1
#
#    LOOSE_BALLS_RECOVERED  OFF_BOXOUTS  DEF_BOXOUTS  BOX_OUT_PLAYER_TEAM_REBS  \
# 0                      8            0           14                        10
# ...
