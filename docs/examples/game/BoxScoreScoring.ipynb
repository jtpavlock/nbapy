# %%
from nbapy import game
import pandas as pd

game_id = '0021900017'

# %% [markdown]
# # players_stats

# %%
pd.DataFrame(game.BoxScoreScoring(game_id).players_stats())
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 0   0021900017  1610612761               TOR   Toronto    1628384
# 1   0021900017  1610612761               TOR   Toronto    1627783
# 2   0021900017  1610612761               TOR   Toronto     201188
# 3   0021900017  1610612761               TOR   Toronto     200768
# 4   0021900017  1610612761               TOR   Toronto    1627832
# 5   0021900017  1610612761               TOR   Toronto    1626181
# 6   0021900017  1610612761               TOR   Toronto     201586
# 7   0021900017  1610612761               TOR   Toronto    1629056
# 8   0021900017  1610612761               TOR   Toronto    1626169
# 9   0021900017  1610612761               TOR   Toronto    1628449
# 10  0021900017  1610612761               TOR   Toronto    1629608
# 11  0021900017  1610612761               TOR   Toronto    1626259
# 12  0021900017  1610612761               TOR   Toronto    1629744
# ...

# %% [markdown]
# # team_stats

# %%
pd.DataFrame(game.BoxScoreScoring(game_id).team_stats())
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION TEAM_CITY     MIN  \
# 0  0021900017  1610612761   Raptors               TOR   Toronto  240:00
# 1  0021900017  1610612738   Celtics               BOS    Boston  240:00
#
#    PCT_FGA_2PT  PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  ...  PCT_PTS_FB  \
# 0        0.538        0.462        0.358           0.019  ...       0.104
# 1        0.651        0.349        0.518           0.036  ...       0.098
#
#    PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_AST_2PM  PCT_UAST_2PM  \
# 0       0.132            0.075          0.340        0.526         0.474
# 1       0.134            0.232          0.482        0.379         0.621
#
#    PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  PCT_UAST_FGM
# 0        0.667         0.333        0.595         0.405
# 1        0.769         0.231        0.500         0.500
#
# [2 rows x 21 columns]
