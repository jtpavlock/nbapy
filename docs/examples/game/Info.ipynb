# %%
from nbapy import game
import pandas as pd
pd.set_option('max_columns', None)

game_id = '0021900017'

# %% [markdown]
# # game_summary

# %%
game.Info(game_id).game_summary()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2019-10-25T00:00:00              1  0021900017               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20191025/TORBOS    1610612738       1610612761   2019
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                          None
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS
# 0            Q4       -           1

# %% [markdown]
# # other_stats

# %%
game.Info(game_id).other_stats()
# Out:
#   LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PTS_PAINT  \
# 0        00  1610612761               TOR   Toronto         36
# 1        00  1610612738               BOS    Boston         54
#
#    PTS_2ND_CHANCE  PTS_FB  LARGEST_LEAD  LEAD_CHANGES  TIMES_TIED  \
# 0               2      11             7            19          12
# 1              21      11             6            19          12
#
#    TEAM_TURNOVERS  TOTAL_TURNOVERS  TEAM_REBOUNDS  PTS_OFF_TO
# 0               0               23              5          26
# 1               1               10              5           8

# %% [markdown]
# # officials

# %%
game.Info(game_id).officials()
# Out:
#    OFFICIAL_ID FIRST_NAME   LAST_NAME JERSEY_NUM
# 0         1193    Michael       Smith       38
# 1         1204      Derek  Richardson       63
# 2         2530         Ed      Malloy       14

# %% [markdown]
# # inactive_players

# %%
game.Info(game_id).inactive_players()
# Out:
#    PLAYER_ID FIRST_NAME         LAST_NAME JERSEY_NUM     TEAM_ID TEAM_CITY  \
# 0     202683       Enes            Kanter       11    1610612738    Boston
# 1    1629605      Tacko              Fall       99    1610612738    Boston
# 2    1629682    Tremont            Waters       51    1610612738    Boston
# 3    1629641      Romeo          Langford       45    1610612738    Boston
# 4    1626178     Rondae  Hollis-Jefferson       4     1610612761   Toronto
# 5    1627775    Patrick             McCaw       22    1610612761   Toronto
# 6    1629052      Oshae          Brissett       12    1610612761   Toronto
# 7    1629044   Shamorie             Ponds       2     1610612761   Toronto
#
#   TEAM_NAME TEAM_ABBREVIATION
# 0   Celtics               BOS
# 1   Celtics               BOS
# 2   Celtics               BOS
# 3   Celtics               BOS
# 4   Raptors               TOR
# 5   Raptors               TOR
# 6   Raptors               TOR
# 7   Raptors               TOR

# %% [markdown]
# # game_info

# %%
game.Info(game_id).game_info()
# Out:
#                   GAME_DATE  ATTENDANCE GAME_TIME
# 0  FRIDAY, OCTOBER 25, 2019       18624      2:19

# %% [markdown]
# # line_score

# %%
game.Info(game_id).line_score()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2019-10-25T00:00:00              1  0021900017  1610612738
# 1  2019-10-25T00:00:00              1  0021900017  1610612761
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_NICKNAME TEAM_WINS_LOSSES  PTS_QTR1  \
# 0               BOS         Boston       Celtics              1-1        22
# 1               TOR        Toronto       Raptors              1-1        21
#
#    PTS_QTR2  PTS_QTR3  PTS_QTR4  PTS_OT1  PTS_OT2  PTS_OT3  PTS_OT4  PTS_OT5  \
# 0        28        26        36        0        0        0        0        0
# 1        28        33        24        0        0        0        0        0
#
#    PTS_OT6  PTS_OT7  PTS_OT8  PTS_OT9  PTS_OT10  PTS
# 0        0        0        0        0         0  112
# 1        0        0        0        0         0  106

# %% [markdown]
# # last_meeting

# %%
game.Info(game_id).last_meeting()
# Out:
#       GAME_ID LAST_GAME_ID   LAST_GAME_DATE_EST  LAST_GAME_HOME_TEAM_ID  \
# 0  0021900017   0021800909  2019-02-26T00:00:00              1610612738
#
#   LAST_GAME_HOME_TEAM_CITY LAST_GAME_HOME_TEAM_NAME  \
# 0                   Boston                  Celtics
#
#   LAST_GAME_HOME_TEAM_ABBREVIATION  LAST_GAME_HOME_TEAM_POINTS  \
# 0                              BOS                          95
#
#    LAST_GAME_VISITOR_TEAM_ID LAST_GAME_VISITOR_TEAM_CITY  \
# 0                 1610612761                     Toronto
#
#   LAST_GAME_VISITOR_TEAM_NAME LAST_GAME_VISITOR_TEAM_CITY1  \
# 0                     Raptors                          TOR
#
#    LAST_GAME_VISITOR_TEAM_POINTS
# 0                            118

# %% [markdown]
# # season_series

# %%
game.Info(game_id).season_series()
# Out:
#       GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        GAME_DATE_EST  \
# 0  0021900017    1610612738       1610612761  2019-10-25T00:00:00
#
#    HOME_TEAM_WINS  HOME_TEAM_LOSSES SERIES_LEADER
# 0               2                 1        Boston

# %% [markdown]
# # available_video

# %%
game.Info(game_id).available_video()
# Out:
#       GAME_ID  VIDEO_AVAILABLE_FLAG  PT_AVAILABLE  PT_XYZ_AVAILABLE  \
# 0  0021900017                     1             1                 1
#
#    WH_STATUS  HUSTLE_STATUS  HISTORICAL_STATUS
# 0          1              1                  0
