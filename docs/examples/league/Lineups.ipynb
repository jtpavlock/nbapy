# %%
from nbapy import league
import pandas as pd
pd.set_option('max_columns', None)

# %% [markdown]
# # lineups

# %%
league.Lineups(season='2019-20').lineups()
# Out:
#      GROUP_SET                                 GROUP_ID  \
# 0      Lineups       -2546-201229-203081-203468-203918-
# 1      Lineups  -203506-203933-1626167-1627734-1628988-
# 2      Lineups    -200794-203115-203914-203999-1627750-
# 3      Lineups         -2546-2772-202355-203081-203468-
# 4      Lineups   -200826-203501-204001-1627827-1629151-
# ...        ...                                      ...
# 1995   Lineups  -201143-203118-1627732-1627788-1629680-
# 1996   Lineups   -200746-201942-201988-1626168-1627854-
# 1997   Lineups     -2544-203076-203484-1627936-1628398-
# 1998   Lineups    -202357-202709-203084-203992-1627741-
# 1999   Lineups   -203497-203903-204060-1627777-1628378-
#
#                                              GROUP_NAME     TEAM_ID  \
# 0     C. Anthony - A. Tolliver - D. Lillard - C. McC...  1610612757
# 1     V. Oladipo - T. Warren - M. Turner - D. Saboni...  1610612754
# 2     P. Millsap - W. Barton - G. Harris - N. Jokic ...  1610612743
# ...
