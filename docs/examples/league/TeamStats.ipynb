# %%
from nbapy import league
import pandas as pd
pd.set_option('max_columns', None)

# %% [markdown]
# # stats

# %%
league.TeamStats(season='2019-20').stats()
# Out:
#        TEAM_ID               TEAM_NAME  GP   W   L  W_PCT   MIN   FGM   FGA  \
# 0   1610612737           Atlanta Hawks  67  20  47  0.299  48.6  40.6  90.6
# 1   1610612738          Boston Celtics  64  43  21  0.672  48.4  41.2  89.6
# 2   1610612751           Brooklyn Nets  64  30  34  0.469  48.6  40.0  90.0
# 3   1610612766       Charlotte Hornets  65  23  42  0.354  48.5  37.3  85.9
# 4   1610612741           Chicago Bulls  65  22  43  0.338  48.2  39.6  88.6
# 5   1610612739     Cleveland Cavaliers  65  19  46  0.292  48.4  40.3  87.9
# 6   1610612742        Dallas Mavericks  67  40  27  0.597  48.3  41.6  90.0
# 7   1610612743          Denver Nuggets  65  43  22  0.662  48.5  41.8  88.9
# 8   1610612765         Detroit Pistons  66  20  46  0.303  48.4  39.3  85.7
# 9   1610612744   Golden State Warriors  65  15  50  0.231  48.4  38.6  88.2
# 10  1610612745         Houston Rockets  64  40  24  0.625  48.2  41.1  90.7
# ...
