# %%
from nbapy import league
import pandas as pd
pd.set_option('max_columns', None)

# %% [markdown]
# # stats

# %%
league.PlayerTrackingStats(season='2019-20').stats()
# Out:
#      PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  GP   W   L  \
# 0       203932       Aaron Gordon  1610612753               ORL  58  28  30
# 1      1628988      Aaron Holiday  1610612754               IND  58  36  22
# 2      1627846        Abdel Nader  1610612760               OKC  48  33  15
# 3      1629690        Adam Mokoka  1610612741               CHI  11   3   8
# 4      1629678  Admiral Schofield  1610612764               WAS  27   9  18
# ..         ...                ...         ...               ...  ..  ..  ..
# 509     203897        Zach LaVine  1610612741               CHI  60  20  40
# 510    1629668   Zach Norvell Jr.  1610612747               LAL   5   2   3
# 511    1629015       Zhaire Smith  1610612755               PHI   7   3   4
# 512    1629627    Zion Williamson  1610612740               NOP  19  10   9
# 513    1629597     Zylan Cheatham  1610612740               NOP   3   2   1
#
#       MIN  CATCH_SHOOT_FGM  CATCH_SHOOT_FGA  CATCH_SHOOT_FG_PCT  \
# 0    33.0              1.1              3.2               0.332
# 1    23.6              0.9              2.2               0.421
# 2    15.8              0.8              2.0               0.388
# 3    10.2              0.5              1.5               0.375
# 4    10.8              0.6              1.7               0.333
# ..    ...              ...              ...                 ...
# 509  34.8              1.2              3.0               0.418
# 510   8.2              0.6              2.0               0.300
# 511   4.6              0.0              0.4               0.000
# 512  29.7              0.1              0.5               0.200
# 513  10.2              0.0              0.7               0.000
#
#      CATCH_SHOOT_PTS  CATCH_SHOOT_FG3M  CATCH_SHOOT_FG3A  CATCH_SHOOT_FG3_PCT  \
# 0                2.9               0.8               2.6                0.320
# 1                2.7               0.9               2.2                0.424
# 2                2.4               0.8               2.0                0.388
# 3                1.6               0.5               1.4                0.400
# 4                1.6               0.5               1.6                0.326
# ..               ...               ...               ...                  ...
# 509              3.7               1.2               2.8                0.426
# 510              1.8               0.6               1.6                0.375
# 511              0.0               0.0               0.4                0.000
# 512              0.3               0.1               0.4                0.286
# 513              0.0               0.0               0.3                0.000
#
#      CATCH_SHOOT_EFG_PCT
# 0                  0.462
# 1                  0.631
# 2                  0.582
# 3                  0.563
# 4                  0.489
# ..                   ...
# 509                0.621
# 510                0.450
# 511                0.000
# 512                0.300
# 513                0.000
#
# [514 rows x 16 columns]
