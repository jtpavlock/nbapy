# %%
from nbapy import league
import pandas as pd

# %% [markdown]
# # stats

# %%
pd.DataFrame(league.PlayerTrackingStats().stats())
# Out:
#      PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  GP   W   L  \
# 0       203932       Aaron Gordon  1610612753               ORL  26  11  15
# 1      1628988      Aaron Holiday  1610612754               IND  28  20   8
# 2      1627846        Abdel Nader  1610612760               OKC  22  13   9
# 3      1629678  Admiral Schofield  1610612764               WAS  15   3  12
# 4       201143         Al Horford  1610612755               PHI  27  17  10
# ..         ...                ...         ...               ...  ..  ..  ..
# 462    1629139      Yuta Watanabe  1610612763               MEM   4   1   3
# 463    1628380       Zach Collins  1610612757               POR   3   2   1
# 464     203897        Zach LaVine  1610612741               CHI  31  12  19
# 465    1629668   Zach Norvell Jr.  1610612747               LAL   2   2   0
# 466    1629597     Zylan Cheatham  1610612740               NOP   2   1   1
#
# ...
