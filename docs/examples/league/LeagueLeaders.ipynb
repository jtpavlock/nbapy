# %%
from nbapy import league
import pandas as pd
pd.set_option('max_columns', None)

# %% [markdown]
# ## players

# %%
league.LeagueLeaders(season='2019-20').players()
# Out:
#      PLAYER_ID  RANK                 PLAYER TEAM  GP   MIN   FGM   FGA  \
# 0       201935     1           James Harden  HOU  61  36.7   9.9  22.7
# 1       203078     2           Bradley Beal  WAS  57  36.0  10.4  22.9
# 2       203507     3  Giannis Antetokounmpo  MIL  57  30.9  10.9  20.0
# 3      1629027     4             Trae Young  ATL  60  35.3   9.1  20.8
# 4       203081     5         Damian Lillard  POR  58  36.9   9.2  20.0
# ..         ...   ...                    ...  ...  ..   ...   ...   ...
# 258     201229   259       Anthony Tolliver  MEM  47  15.6   1.1   3.3
# 259     203585   260        Rodney McGruder  LAC  50  15.0   1.2   3.1
# 260    1628400   261           Semi Ojeleye  BOS  61  14.6   1.1   2.6
# 261     203521   262    Matthew Dellavedova  CLE  57  14.4   1.1   3.1
# 262    1629048   263           Goga Bitadze  IND  49   8.4   1.2   2.6
#
#      FG_PCT  FG3M  FG3A  FG3_PCT   FTM   FTA  FT_PCT  OREB  DREB   REB  AST  \
# ...
