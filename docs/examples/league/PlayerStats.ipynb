# %%
from nbapy import league
import pandas as pd
pd.set_option('max_columns', None)

# %% [markdown]
# # stats

# %%
league.PlayerStats(season='2019-20').stats()
# Out:
#      PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP   W  \
# 0       203932       Aaron Gordon  1610612753               ORL  24.0  58  28
# 1      1628988      Aaron Holiday  1610612754               IND  23.0  58  36
# 2      1627846        Abdel Nader  1610612760               OKC  26.0  48  33
# 3      1629690        Adam Mokoka  1610612741               CHI  21.0  11   3
# 4      1629678  Admiral Schofield  1610612764               WAS  23.0  27   9
# ..         ...                ...         ...               ...   ...  ..  ..
# 509     203897        Zach LaVine  1610612741               CHI  25.0  60  20
# 510    1629668   Zach Norvell Jr.  1610612747               LAL  22.0   5   2
# 511    1629015       Zhaire Smith  1610612755               PHI  21.0   7   3
# 512    1629627    Zion Williamson  1610612740               NOP  19.0  19  10
# 513    1629597     Zylan Cheatham  1610612740               NOP  24.0   3   2
#
# ...
