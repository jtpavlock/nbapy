# %%
from nbapy import league
import pandas as pd

# %% [markdown]
# # stats

# %%
pd.DataFrame(league.PlayerStats().stats())
# Out:
#      PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP   W  \
# 0       203932       Aaron Gordon  1610612753               ORL  24.0  26  11
# 1      1628988      Aaron Holiday  1610612754               IND  23.0  28  20
# 2      1627846        Abdel Nader  1610612760               OKC  26.0  22  13
# 3      1629678  Admiral Schofield  1610612764               WAS  22.0  15   3
# 4       201143         Al Horford  1610612755               PHI  33.0  27  17
# ..         ...                ...         ...               ...   ...  ..  ..
# 462    1629139      Yuta Watanabe  1610612763               MEM  25.0   4   1
# 463    1628380       Zach Collins  1610612757               POR  22.0   3   2
# 464     203897        Zach LaVine  1610612741               CHI  24.0  31  12
# 465    1629668   Zach Norvell Jr.  1610612747               LAL  22.0   2   2
# 466    1629597     Zylan Cheatham  1610612740               NOP  24.0   2   1
#
# ...
