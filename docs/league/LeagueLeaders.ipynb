# %%
from nbapy import league
import pandas as pd

# %% [markdown]
# # stats

# %%
pd.DataFrame(league.LeagueLeaders().players())
# Out:
#      PLAYER_ID  RANK                 PLAYER TEAM  GP   MIN   FGM   FGA  \
# 0       201935     1           James Harden  HOU  29  37.6  11.2  24.9
# 1       203507     2  Giannis Antetokounmpo  MIL  30  31.1  11.5  20.3
# 2      1629029     3            Luka Doncic  DAL  25  32.2   9.4  19.6
# 3      1629027     4             Trae Young  ATL  29  35.6   9.5  21.4
# 4       203078     5           Bradley Beal  WAS  28  37.1   9.5  21.5
# ..         ...   ...                    ...  ...  ..   ...   ...   ...
# 270    1629750   271          Javonte Green  BOS  21   8.0   1.2   2.3
# 271    1628400   272           Semi Ojeleye  BOS  27  15.6   1.0   2.4
# 272     203521   273    Matthew Dellavedova  CLE  27  13.0   0.8   2.9
# 273     200757   274        Thabo Sefolosha  HOU  23   9.9   0.7   2.1
# 274     201162   275           Jared Dudley  LAL  21   8.5   0.5   1.3
#
#      FG_PCT  FG3M  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV   PTS  \
# ...
