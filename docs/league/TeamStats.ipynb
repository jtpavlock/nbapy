# %%
from nbapy import league
import pandas as pd

# %% [markdown]
# # stats

# %%
pd.DataFrame(league.TeamStats().stats())
# Out:
#        TEAM_ID               TEAM_NAME  GP   W   L  W_PCT   MIN   FGM   FGA  \
# 0   1610612737           Atlanta Hawks  30   6  24  0.200  48.5  40.0  89.8
# 1   1610612738          Boston Celtics  27  20   7  0.741  48.2  40.6  89.0
# 2   1610612751           Brooklyn Nets  29  16  13  0.552  48.5  40.8  91.2
# 3   1610612766       Charlotte Hornets  33  13  20  0.394  48.2  37.7  86.3
# 4   1610612741           Chicago Bulls  31  12  19  0.387  48.3  38.4  88.8
# 5   1610612739     Cleveland Cavaliers  29   8  21  0.276  48.2  38.7  87.8
# 6   1610612742        Dallas Mavericks  29  19  10  0.655  48.3  41.5  89.7
# 7   1610612743          Denver Nuggets  28  20   8  0.714  48.5  40.9  90.0
# 8   1610612765         Detroit Pistons  30  11  19  0.367  48.0  39.6  85.2
# 9   1610612744   Golden State Warriors  30   6  24  0.200  48.3  38.1  88.6
# 10  1610612745         Houston Rockets  29  20   9  0.690  48.3  41.5  91.1
# ...
