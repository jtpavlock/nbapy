# %%
from nbapy import league
import pandas as pd

# %% [markdown]
# # lineups

# %%
pd.DataFrame(league.Lineups().lineups())
# Out:
#      GROUP_SET                                 GROUP_ID  \
# 0      Lineups       -2546-201229-203081-203468-203918-
# 1      Lineups  -200768-201586-1627775-1627832-1628384-
# 2      Lineups    -200794-203115-203914-203999-1627750-
# 3      Lineups  -200768-201188-1626181-1627783-1628384-
# 4      Lineups  -203087-203933-1626167-1627734-1627763-
# ...        ...                                      ...
# 1995   Lineups  -203083-204038-1626174-1628379-1628971-
# 1996   Lineups   -201571-203082-203095-1628371-1628964-
# 1997   Lineups    -202357-202709-203084-203992-1627741-
# 1998   Lineups    -203115-203486-203914-203924-1627750-
# 1999   Lineups  -202684-203903-1626224-1629012-1629636-
#
#                                              GROUP_NAME     TEAM_ID  \
# 0     C. Anthony - A. Tolliver - D. Lillard - C. McC...  1610612757
# 1     K. Lowry - S. Ibaka - P. McCaw - F. VanVleet -...  1610612761
# 2     P. Millsap - W. Barton - G. Harris - N. Jokic ...  1610612743
# ...
