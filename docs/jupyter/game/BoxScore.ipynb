# %%
from nbapy import game
import pandas as pd

game_id = '0021900017'

# %% [markdown]
# # players_stats

# %%
pd.DataFrame(game.BoxScore(game_id).players_stats())
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 0   0021900017  1610612761               TOR   Toronto    1628384
# 1   0021900017  1610612761               TOR   Toronto    1627783
# 2   0021900017  1610612761               TOR   Toronto     201188
# 3   0021900017  1610612761               TOR   Toronto     200768
# 4   0021900017  1610612761               TOR   Toronto    1627832
# 5   0021900017  1610612761               TOR   Toronto    1626181
# 6   0021900017  1610612761               TOR   Toronto     201586
# 7   0021900017  1610612761               TOR   Toronto    1629056
# 8   0021900017  1610612761               TOR   Toronto    1626169
# 9   0021900017  1610612761               TOR   Toronto    1628449
# 10  0021900017  1610612761               TOR   Toronto    1629608
# 11  0021900017  1610612761               TOR   Toronto    1626259
# 12  0021900017  1610612761               TOR   Toronto    1629744
# ...

# %% [markdown]
# # team_stats

# %%
pd.DataFrame(game.BoxScore(game_id).team_stats())
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION TEAM_CITY     MIN  FGM  \
# 0  0021900017  1610612761   Raptors               TOR   Toronto  240:00   37
# 1  0021900017  1610612738   Celtics               BOS    Boston  240:00   42
#
#    FGA  FG_PCT  FG3M  ...  OREB  DREB  REB  AST  STL  BLK  TO  PF  PTS  \
# 0   78   0.474    18  ...     5    41   46   22    2    6  23  28  106
# 1  109   0.385    13  ...    21    35   56   21   10    8   9  20  112
#
#    PLUS_MINUS
# 0        -6.0
# 1         6.0
#
# [2 rows x 25 columns]

# %% [markdown]
# # team_starter_bench_stats

# %%
pd.DataFrame(game.BoxScore(game_id).team_starter_bench_stats())
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION TEAM_CITY  \
# 0  0021900017  1610612761   Raptors               TOR   Toronto
# 1  0021900017  1610612761   Raptors               TOR   Toronto
# 2  0021900017  1610612738   Celtics               BOS    Boston
# 3  0021900017  1610612738   Celtics               BOS    Boston
#
#   STARTERS_BENCH     MIN  FGM  FGA  FG_PCT  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0       Starters  180:06   28   64   0.438  ...   0.909     5    25   30   20
# 1          Bench   59:54    9   14   0.643  ...   0.667     0    16   16    2
# 2       Starters  161:18   32   83   0.386  ...   0.929    12    26   38   13
# 3          Bench   59:43    7   23   0.304  ...   1.000     7     4   11    7
#
#    STL  BLK  TO  PF  PTS
# 0    2    3  18  19   80
# 1    0    3   5   9   26
# 2    5    6   6  10   88
# 3    3    1   2   6   18
#
# [4 rows x 25 columns]
