# %%
from nbapy import draft_combine
import pandas as pd

# %% [markdown]
# # stats

# %%
pd.DataFrame(draft_combine.Summary().stats())
# Out:
#    SEASON  PLAYER_ID FIRST_NAME         LAST_NAME               PLAYER_NAME  \
# 0    2019    1629638    Nickeil  Alexander-Walker  Nickeil Alexander-Walker
# 1    2019    1629628         RJ           Barrett                RJ Barrett
# 2    2019    1629646    Charles            Bassey            Charles Bassey
# 3    2019    1629647     Darius            Bazley             Darius Bazley
# 4    2019    1629626        Bol               Bol                   Bol Bol
# ..    ...        ...        ...               ...                       ...
# 72   2019    1629632       Coby             White                Coby White
# 73   2019    1629025       Kris            Wilkes               Kris Wilkes
# 74   2019    1629684      Grant          Williams            Grant Williams
# 75   2019    1629627       Zion        Williamson           Zion Williamson
# 76   2019    1629685      Dylan           Windler             Dylan Windler
#
# ...
