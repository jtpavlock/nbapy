# %%
from nbapy import draft_combine
import pandas as pd

# %% [markdown]
# # stats

# %%
pd.DataFrame(draft_combine.SpotShooting().stats())
# Out:
#     TEMP_PLAYER_ID  PLAYER_ID FIRST_NAME         LAST_NAME  \
# 0          1629638    1629638    Nickeil  Alexander-Walker
# 1          1629628    1629628         RJ           Barrett
# 2          1629646    1629646    Charles            Bassey
# 3          1629647    1629647     Darius            Bazley
# 4          1629626    1629626        Bol               Bol
# ..             ...        ...        ...               ...
# 72         1629632    1629632       Coby             White
# 73         1629025    1629025       Kris            Wilkes
# 74         1629684    1629684      Grant          Williams
# 75         1629627    1629627       Zion        Williamson
# 76         1629685    1629685      Dylan           Windler
#
#                  PLAYER_NAME POSITION  FIFTEEN_CORNER_LEFT_MADE  \
# 0   Nickeil Alexander-Walker       SG                       NaN
# 1                 RJ Barrett       SF                       NaN
# ...
